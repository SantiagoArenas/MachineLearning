# %%
# Import packages required for matrix and graphic representations
import numpy as np
import pandas as pd

# Data Visualisation
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Configuración warnings
# ------------------------------------------------------------------------------
import warnings
#warnings.filterwarnings('once')
warnings.filterwarnings('ignore')

# %%
# Data Loading

Carseats = pd.read_csv('Carseats.csv')

print ("Clean Size Carseats", Carseats.shape)

print("Type", type(Carseats))

Carseats.head()
# Out:
# Clean Size Carseats (400, 11)
# Type <class 'pandas.core.frame.DataFrame'>
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
Carseats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    object
#  7   Age          400 non-null    int64
#  8   Education    400 non-null    int64
#  9   Urban        400 non-null    object
#  10  US           400 non-null    object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 34.5+ KB

# %%
Carseats.isnull().sum()*100/Carseats.shape[0]
# Out:
# Sales          0.0
# CompPrice      0.0
# Income         0.0
# Advertising    0.0
# Population     0.0
# Price          0.0
# ShelveLoc      0.0
# Age            0.0
# Education      0.0
# Urban          0.0
# US             0.0
# dtype: float64

# %%
print(Carseats["ShelveLoc"].value_counts())
print(Carseats["Urban"].value_counts())
print(Carseats["US"].value_counts())
# Out:
# Medium    219
# Bad        96
# Good       85
# Name: ShelveLoc, dtype: int64
# Yes    282
# No     118
# Name: Urban, dtype: int64
# Yes    258
# No     142
# Name: US, dtype: int64

# %%
usTrue = pd.get_dummies(pd.Series(list(Carseats['US'])), drop_first=True)  
urbanTrue = pd.get_dummies(pd.Series(list(Carseats['Urban'])), drop_first=True)  
shelvePos = pd.get_dummies(pd.Series(list(Carseats['ShelveLoc'])), drop_first=True)

data=pd.get_dummies(Carseats, columns=['ShelveLoc','Urban','US'], prefix="dmy",drop_first=True)  # drop_first removes 0 values leaving k-1 levels
data.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0   9.50        138      73           11         276    120   42         17
# 1  11.22        111      48           16         260     83   65         10
# 2  10.06        113      35           10         269     80   59         12
# 3   7.40        117     100            4         466     97   55         14
# 4   4.15        141      64            3         340    128   38         13
#
#    dmy_Good  dmy_Medium  dmy_Yes  dmy_Yes
# 0         0           0        1        1
# 1         1           0        1        1
# 2         0           1        1        1
# 3         0           1        1        1
# 4         0           0        1        0

# %%
data.iloc[:, 2:]
# Out:
#      Income  Advertising  Population  Price  Age  Education  dmy_Good  \
# 0        73           11         276    120   42         17         0
# 1        48           16         260     83   65         10         1
# 2        35           10         269     80   59         12         0
# 3       100            4         466     97   55         14         0
# 4        64            3         340    128   38         13         0
# ..      ...          ...         ...    ...  ...        ...       ...
# 395     108           17         203    128   33         14         1
# 396      23            3          37    120   55         11         0
# 397      26           12         368    159   40         18         0
# 398      79            7         284     95   50         12         0
# 399      37            0          27    120   49         16         1
#
#      dmy_Medium  dmy_Yes  dmy_Yes
# 0             0        1        1
# 1             0        1        1
# ...

# %%
from sklearn.model_selection import train_test_split

# Dividing the dataset in training and test
# ==============================================================================
set.seed(123)
X = data.iloc[:, 2:]
y = data["Sales"]


X_train, X_test, y_train, y_test = train_test_split(
                                        X,
                                        #y.values.reshape(-1,1),
                                        y,
                                        train_size   = 0.8,  # 70% for training
                                        random_state = 1234,
                                        shuffle      = True
                                        )

# %%
urbanTrue.head()
# Out:
#    Yes
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
